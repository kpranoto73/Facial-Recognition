# %%
import time
start = time.time()

import face_recognition
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#For adding new, commandF tester and replace it with name
# tester_1_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/tester/tester_1.jpg")
# tester_1_face_encoding = face_recognition.face_encodings(tester_1_image)[0]
# tester_2_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/tester/tester_2.jpg")
# tester_2_face_encoding = face_recognition.face_encodings(tester_2_image)[0]

# #Load Cahyadi picture and learn how to recognize it.
# cahyadi_1_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Cahyadi/cahyadi_1.jpg")
# cahyadi_1_face_encoding = face_recognition.face_encodings(cahyadi_1_image)[0]
# cahyadi_2_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Cahyadi/cahyadi_4.jpg")
# cahyadi_2_face_encoding = face_recognition.face_encodings(cahyadi_2_image)[0]

# #Load Husni picture and learn how to recognize it.
# husni_1_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Husni/husni_4.jpg")
# husni_1_face_encoding = face_recognition.face_encodings(husni_1_image)[0]
# husni_2_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Husni/husni_5.jpg")
# husni_2_face_encoding = face_recognition.face_encodings(husni_2_image)[0]

# # #Load Faye picture and learn how to recognize it.
# faye_1_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Faye/faye_1.jpg")
# faye_1_face_encoding = face_recognition.face_encodings(faye_1_image)[0]
# faye_2_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Faye/faye_5.jpg")
# faye_2_face_encoding = face_recognition.face_encodings(faye_2_image)[0]

# #Load Eci picture and learn how to recognize it.
# eci_1_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Eci/eci_1.jpg")
# eci_1_face_encoding = face_recognition.face_encodings(eci_1_image)[0]
# eci_2_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Eci/eci_3.jpg")
# eci_2_face_encoding = face_recognition.face_encodings(eci_2_image)[0]

# #Load Nava picture and learn how to recognize it.
# nava_1_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Nava/nava_1.jpg")
# nava_1_face_encoding = face_recognition.face_encodings(nava_1_image)[0]
# nava_2_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Nava/nava_2.jpg")
# nava_2_face_encoding = face_recognition.face_encodings(nava_2_image)[0]

# #Load Ganta picture and learn how to recognize it.
# ganta_1_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Ganta/ganta_1.jpg")
# ganta_1_face_encoding = face_recognition.face_encodings(ganta_1_image)[0]
# ganta_2_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Ganta/ganta_2.jpg")
# ganta_2_face_encoding = face_recognition.face_encodings(ganta_2_image)[0]

# # #Load Toto picture and learn how to recognize it.
# toto_1_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Toto/toto_1.jpg")
# toto_1_face_encoding = face_recognition.face_encodings(toto_1_image)[0]
# toto_2_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Toto/toto_2.jpg")
# toto_2_face_encoding = face_recognition.face_encodings(toto_2_image)[0]

# #Load Putri picture and learn how to recognize it.
# putri_1_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Putri/putri_1.jpg")
# putri_1_face_encoding = face_recognition.face_encodings(putri_1_image)[0]
# putri_2_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Putri/putri_2.jpg")
# putri_2_face_encoding = face_recognition.face_encodings(putri_2_image)[0]

# #Load Agus picture and learn how to recognize it.
# agus_1_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Agus/agus_1.jpg")
# agus_1_face_encoding = face_recognition.face_encodings(agus_1_image)[0]
# agus_2_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Agus/agus_2.jpg")
# agus_2_face_encoding = face_recognition.face_encodings(agus_2_image)[0]

# #Load Gede picture and learn how to recognize it.
# gede_1_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Gede/gede_1.jpg")
# gede_1_face_encoding = face_recognition.face_encodings(gede_1_image)[0]
# gede_2_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Gede/gede_2.jpg")
# gede_2_face_encoding = face_recognition.face_encodings(gede_2_image)[0]

# # Load Oky picture and learn how to recognize it.
# oky_1_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Oky/oky_1.jpg")
# oky_1_face_encoding = face_recognition.face_encodings(oky_1_image)[0]
# oky_2_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Oky/oky_2.jpg")
# oky_2_face_encoding = face_recognition.face_encodings(oky_2_image)[0]

# #Load Kevin picture and learn how to recognize it.
# kevin_1_image = face_recognition.load_image_file("/Users/kp/Desktop/Generali/Facial Recognition/Finished/known_people/Kevin/kevin_1.jpg")
# kevin_1_face_encoding = face_recognition.face_encodings(kevin_1_image)[0]

#Initialize Loaded Images towards Face Encoding and flagging them with name
known_face_encodings = [
#     cahyadi_1_face_encoding, cahyadi_2_face_encoding,
#     husni_1_face_encoding, husni_2_face_encoding,
#     faye_1_face_encoding, faye_2_face_encoding,
#     eci_1_face_encoding, eci_2_face_encoding,
#     nava_1_face_encoding, nava_2_face_encoding,
#     ganta_1_face_encoding, ganta_2_face_encoding,
#     toto_1_face_encoding, toto_2_face_encoding,
#     putri_1_face_encoding, putri_2_face_encoding,
#     agus_1_face_encoding, agus_2_face_encoding,
#     gede_1_face_encoding, gede_2_face_encoding,
#     oky_1_face_encoding, oky_2_face_encoding,
#     kevin_1_face_encoding
]
known_face_names = [
#     "Cahyadi", "Cahyadi",
#     "Husni", "Husni",
#     "Faye", "Faye",
#     "Eci", "Eci",
#     "Nava", "Nava",
#     "Ganta", "Ganta",
#     "Toto", "Toto",
#     "Putri", "Putri",
#     "Agus", "Agus",
#     "Gede", "Gede",
#     "Oky", "Oky",
#     "Kevin"
]

#Initialize some variables
face_locations = []
face_encodings = []
face_names = []
process_this_frame = True

end = time.time()
print (end - start)

# %%
#Get a reference to webcam
video_capture = cv2.VideoCapture(0)

while True:
    #Grab a single frame of video
    ret, frame = video_capture.read()

    #Resize frame of video to 1/4 size for faster face recognition processing
    small_frame = cv2.resize(frame, (0, 0), fx=0.25, fy=0.25)

    #Convert the image from BGR color to RGB color 
    rgb_small_frame = small_frame[:, :, ::-1]

    #Only process every other frame of video to save time
    if process_this_frame:
        #Find all the faces and face encodings in the current frame of video
        face_locations = face_recognition.face_locations(rgb_small_frame)
        face_encodings = face_recognition.face_encodings(rgb_small_frame, face_locations)

        face_names = []
        for face_encoding in face_encodings:
            #See if the face is a match for the known face(s)
            matches = face_recognition.compare_faces(known_face_encodings, face_encoding, tolerance = 0.5)
            name = "Unknown"

            #Or instead, use the known face with the smallest distance to the new face
            face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
            best_match_index = np.argmin(face_distances)
            if matches[best_match_index]:
                name = known_face_names[best_match_index]
            face_names.append(name)
    process_this_frame = not process_this_frame

    #Display the results
    for (top, right, bottom, left), name in zip(face_locations, face_names):
        top *= 4
        right *= 4
        bottom *= 4
        left *= 4

        #Draw a box around the face
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

        #Draw a label with a name below the face
        cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
        font = cv2.FONT_HERSHEY_DUPLEX
        cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

    #Display the resulting image
    cv2.imshow('Video', frame)

    #Hit 'q' on the keyboard to quit!
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

#Release handle to the webcam
cv2.destroyAllWindows()
video_capture.release()
